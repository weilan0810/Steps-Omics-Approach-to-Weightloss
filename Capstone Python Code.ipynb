# %%
##STEP COUNT

import pandas as pd
step_count=pd.read_csv('step_count.csv')

#display step count df
step_count
# Out:
#        studyID    Steps      Date  Weight    BMI
# 0         2001   2931.0  11/17/14  253.40  36.24
# 1         2001   2264.0  11/18/14  253.55  36.26
# 2         2001   5347.0  11/19/14  253.71  36.28
# 3         2001   5924.0  11/20/14  253.87  36.30
# 4         2001   6961.0  11/21/14  254.02  36.33
# 5         2001  10359.0  11/22/14  254.18  36.35
# 6         2001   7234.0  11/23/14  254.34  36.37
# 7         2001   1760.0  11/24/14  254.49  36.39
# 8         2001   6920.0  11/25/14  254.65  36.42
# 9         2001   4786.0  11/26/14  254.81  36.44
# 10        2001   6071.0  11/27/14  254.96  36.46
# 11        2001   7517.0  11/28/14  255.12  36.48
# 12        2001   6586.0  11/29/14  255.27  36.51
# 13        2001   4956.0  11/30/14  255.43  36.53
# 14        2001   7573.0   12/1/14  255.60  36.55
# 15        2001   7548.0   12/2/14  253.20  36.21
# 16        2001   7166.0   12/3/14  250.80  35.87
# 17        2001   6441.0   12/4/14  248.40  35.52
# ...

# %%
#Imports Gene Expression data (counts file)
counts=pd.read_csv('counts.csv', index_col = 0)
#Transposes rows into columns to make "studyID" as the dataframe index
#gene_counts = counts.transpose()
#gene_counts['studyID'] = list(counts)

#gene_counts_df = gene_counts.set_index("studyID")

#gene_counts_df = gene_counts_df.drop(labels = ['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'], axis = 1)

#gene_counts_df
gene_counts_df = counts.drop(labels = ['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'], axis = 0)
gene_counts_df
# Out:
#                           2001-01  2001-02  2001-03  2002-01  2002-02  \
# ENSG00000223972.5               0        0        0        0        0
# ENSG00000227232.5               0        0        0        0        0
# ENSG00000278267.1               0        0        0        0        0
# ENSG00000243485.5               0        0        0        0        0
# ENSG00000284332.1               0        0        0        0        0
# ENSG00000237613.2               0        0        0        0        0
# ENSG00000268020.3               0        0        0        0        0
# ENSG00000240361.2               0        0        0        0        0
# ENSG00000186092.6               0        0        0        0        0
# ENSG00000238009.6               0        0        0        0        0
# ENSG00000239945.1               0        0        0        0        0
# ENSG00000233750.3               0        0        0        0        0
# ...

# %%
##ANTHRO RED

anthro_red_new = pd.read_csv('anthro_red_new.csv')
del anthro_red_new['Unnamed: 0']
anthro_red_new = anthro_red_new[(anthro_red_new['Days'] >= 0)]

#display anthro red df
anthro_red_new
# Out:
#     studyID StudyGroup   Days
# 0      2002        Red  158.0
# 1      2004        Red  115.0
# 2      2005        Red  138.0
# 3      2006        Red  137.0
# 4      2010        Red   91.0
# 5      2012        Red  147.0
# 6      2013        Red   98.0
# 7      2022        Red   85.0
# 8      2023        Red  101.0
# 9      2025        Red  107.0
# 10     2026        Red   91.0
# 11     2027        Red   83.0
# 12     2031        Red   91.0
# 13     2040        Red   96.0
# 14     2041        Red   79.0
# 15     2043        Red  117.0
# 16     2045        Red   81.0
# 17     2047        Red  103.0
# 18     2048        Red  106.0
# 21     2054        Red  106.0
# 22     2057        Red   89.0
# 23     2058        Red  112.0
# 24     2059        Red  103.0
# 25     2060        Red   83.0
# 26     2066        Red  150.0
# 27     2070        Red  116.0
# 28     2071        Red   90.0
# 29     2078        Red   94.0
# 30     2080        Red   91.0
# 31     2081        Red   91.0
# ...

# %%
##ANTHRO BLUE

anthro_blue_new = pd.read_csv('anthro_blue_new.csv')
del anthro_blue_new['Unnamed: 0']
anthro_blue_new = anthro_blue_new[(anthro_blue_new['Days'] >= 0)]

#display anthro red df
anthro_blue_new
# Out:
#     studyID StudyGroup   Days
# 0      2001       Blue  106.0
# 1      2003       Blue  128.0
# 2      2007       Blue  153.0
# 3      2008       Blue  106.0
# 5      2014       Blue  161.0
# 6      2017       Blue  113.0
# 7      2020       Blue  118.0
# 8      2021       Blue  117.0
# 9      2024       Blue  133.0
# 10     2028       Blue  155.0
# 11     2029       Blue  120.0
# 12     2032       Blue  197.0
# 13     2033       Blue  155.0
# 14     2035       Blue  112.0
# 15     2037       Blue  133.0
# 16     2039       Blue  134.0
# 17     2044       Blue  148.0
# 18     2046       Blue  147.0
# 19     2050       Blue  114.0
# 21     2055       Blue  163.0
# 22     2056       Blue  103.0
# 23     2063       Blue  155.0
# 25     2067       Blue  162.0
# 26     2069       Blue  119.0
# 27     2072       Blue  126.0
# 28     2074       Blue  119.0
# 29     2075       Blue  136.0
# 31     2082       Blue  189.0
# 32     2084       Blue  126.0

# %%
##RED LABS

Red_labs = pd.read_csv('Red_labs.csv')
Red_labs.dropna(inplace = True)

#display red labs df
Red_labs
# Out:
#     studyID StudyGroup  Age  Gender  MO3Glucose  MO3A1C  MO6Glucose  MO6A1C
# 0      2002        Red   38       1        94.0     5.9        88.0     6.0
# 1      2004        Red   60       0       103.0     6.2       101.0     6.3
# 3      2006        Red   48       1       112.0     6.4       105.0     6.4
# 4      2010        Red   25       1        76.0     5.4        76.0     5.5
# 5      2012        Red   29       0        85.0     5.6        93.0     5.6
# 6      2013        Red   68       1        87.0     5.9        82.0     5.7
# 7      2022        Red   38       1        85.0     5.7        82.0     6.0
# 8      2023        Red   26       1        78.0     5.3        79.0     5.1
# 9      2025        Red   41       0        94.0     6.1        95.0     5.6
# 10     2026        Red   45       0        90.0     5.9        91.0     5.9
# 11     2027        Red   27       1        87.0     5.5        93.0     5.4
# ...

# %%
##BLUE LABS
Blue_labs = pd.read_csv('Blue_labs.csv')
Blue_labs.dropna(inplace = True)

#display blue labs df
Blue_labs
# Out:
#     studyID StudyGroup  Age  Gender  Bglucose  BA1C  MO3Glucose  MO3A1C
# 0      2001       Blue   28       0       101   5.6        83.0     5.6
# 1      2003       Blue   26       1        82   6.3        76.0     6.4
# 3      2008       Blue   46       1        88   5.5        80.0     5.2
# 5      2014       Blue   47       0        98   6.5        78.0     6.0
# 6      2017       Blue   43       0       100   5.9        89.0     5.9
# 7      2020       Blue   39       0        84   5.4        84.0     5.3
# 8      2021       Blue   61       1        98   5.8        93.0     5.8
# 9      2024       Blue   31       1        79   5.7        72.0     5.8
# 10     2028       Blue   29       0        90   5.5        93.0     5.7
# 11     2029       Blue   65       0       100   5.6        98.0     5.7
# 12     2032       Blue   37       0        64   5.8        86.0     5.8
# 13     2033       Blue   47       0        77   5.6       102.0     5.8
# ...
