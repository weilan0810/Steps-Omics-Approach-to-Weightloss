# %%
import pandas as pd
HGNC=pd.read_csv('HGNC.csv')

# %%
HGNC
# Out:
#           HGNC ID           Status Approved symbol  \
# 0          HGNC:5         Approved            A1BG
# 1      HGNC:37133         Approved        A1BG-AS1
# 2      HGNC:24086         Approved            A1CF
# 3          HGNC:7         Approved             A2M
# 4      HGNC:27057         Approved         A2M-AS1
# 5      HGNC:23336         Approved           A2ML1
# 6      HGNC:41022         Approved       A2ML1-AS1
# 7      HGNC:41523         Approved       A2ML1-AS2
# 8          HGNC:8         Approved           A2MP1
# 9      HGNC:30005         Approved         A3GALT2
# 10     HGNC:18149         Approved          A4GALT
# 11     HGNC:17968         Approved           A4GNT
# 12         HGNC:1  Entry Withdrawn           A12M1
# 13         HGNC:2  Entry Withdrawn           A12M2
# 14         HGNC:3  Entry Withdrawn           A12M3
# 15         HGNC:4  Entry Withdrawn           A12M4
# 16     HGNC:13666         Approved            AAAS
# ...

# %%
counts=pd.read_csv('counts.csv', index_col = 0)
gene_counts_df = counts.drop(labels = ['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'], axis = 0)
gene_counts_df
# Out:
#                     2001-01  2001-02  2001-03  2002-01  2002-02  2002-03  \
# ENSG00000223972.5         0        0        0        0        0        0
# ENSG00000227232.5         0        0        0        0        0        0
# ENSG00000278267.1         0        0        0        0        0        0
# ENSG00000243485.5         0        0        0        0        0        0
# ENSG00000284332.1         0        0        0        0        0        0
# ENSG00000237613.2         0        0        0        0        0        0
# ENSG00000268020.3         0        0        0        0        0        0
# ENSG00000240361.2         0        0        0        0        0        0
# ENSG00000186092.6         0        0        0        0        0        0
# ENSG00000238009.6         0        0        0        0        0        0
# ENSG00000239945.1         0        0        0        0        0        0
# ENSG00000233750.3         0        0        0        0        0        0
# ...

# %%
for i in len(gene_counts_df.shape()):
    for j in len(HGNC.shape()):
        if gene_counts_df['geneID'][i] == HGNC['Ensembl gene ID'][j] :
            gene_counts_df['geneID'][i] == HGNC['HGNC ID'][j]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-88b4a0b3689b> in <module>()
# ----> 1 for i in len(gene_counts_df.shape()):
#       2     for j in len(HGNC.shape()):
#       3         if gene_counts_df['geneID'][i] == HGNC['Ensembl gene ID'][j] :
#       4             gene_counts_df['geneID'][i] == HGNC['HGNC ID'][j]
#
# TypeError: 'tuple' object is not callable
